# %%
#W2A1
print("Hello World!")
# Out:
# Hello World!

# %%
#W2A2
print("xin chao",input("hay nhap ten cua ban"))
# Out:
# xin chao MCN

# %%
#W2A3
a = int(input("a = "))
b = int(input("b = "))
x = a + b
y = a - b
z = a * b
w = a / b
w = round(w, 2)
print("tong =", x)
print("hieu =", y)
print("tich =", z)
print("thuong =", w)
# Out:
# tong = 9
# hieu = -3
# tich = 18
# thuong = 0.5

# %%
#W2A4
a1, b1, c1, a2, b2, a3 = map(float, input(
    "nhap lan luot 6 so ").split())  #The map() function in Python is a built-in function that applies a given function to each item
TB = ((a1 + b1 + c1) + (a2 + b2) * 2 + (a3) * 3) / 10
Tb = round(TB, 1)
print("Diem trung binh la:", Tb)
# Out:
# Diem trung binh la: 4.8

# %%
#W2A5
a, b = map(int, input("hay nhap vao hai so a, b: ").split())
x = a**b
print(f"{a}^{b} =",x)
# Out:
# 3^6 = 729

# %%
#W2A6
a = input("hay nhap mot chu cai thuong bat ki ")
b = ord(a)
while b < 97 or b > 122:
  a = input("nhap lai")
  b = ord(a)
print(f"ma unicode cua {a} la:", ord(a))
a = a.upper()
print(f"chu cai in hoa {a} la:", a)
# Out:
# ma unicode cua n la: 110
# chu cai in hoa N la: N

# %%
#W2A7
print("A = ((13 ** 2) * 3) + 5 = ",((13 ** 2) * 3) + 5)
print("B = 13**2*3 + 5 = ",13**2*3 + 5)
# Out:
# A = ((13 ** 2) * 3) + 5 =  512
# B = 13**2*3 + 5 =  512

# %%
#W2A8
C = float(input("nhap nhiet do C"))
F = 9/5*C + 32
round(F,2)
print("nhiet do F la",F)
# Out:
# nhiet do F la 86.0

# %%
#W2A9
x = float(input("gia cua chiec dong ho (USD)"))
print("so tien Dat chi de mua dong ho", round(x*1.4 + 10,2))
# Out:
# so tien Dat chi de mua dong ho 24.0

# %%
#W2A10
a = (input("nhap lan luot ten 3 nguoi ").split())
print(f"{a[2], a[1], a[0]}")
# Out:
# ('C', 'B', 'A')

# %%
#W2A11
a=int(input("so gio"))
b=int(input("so phut"))
print("so giay la: ",a*3600+b*60)
# Out:
# so giay la:  3900

# %%
#W2A12
n = int(input())
print("stickers_needed", 6 * n * n)
# Out:
# stickers_needed 6144

# %%
#W2A13
a = int(input())
b = int(input())
print(f"tich {a} va {b} la: ",a*b)
# Out:
# tich 3 va 2 la:  6

# %%
#W2A14
a=float(input("a"))
b=float(input("b"))
a, b =b, a
print(f"a = {a} va b = {b}")
# Out:
# a = 2.0 va b = 3.0

# %%
#W2A15
n = int(input("nhap so nguyen n"))
x = 6 * n * (n - 1) + 1
print("so sao la: ",x)
# Out:
# so sao la:  13

# %%
#W2A16
print("Spring\nSummer\nAutumn\nWinter")
# Out:
# Spring
# Summer
# Autumn
# Winter

# %%
#W2A17
print("*\n***\n*****")
# Out:
# *
# ***
# *****

# %%
#W2A18
print("### # #  ### ###\n #  #  #  #   #\n #  #  #  #   #\n #  #  #  #   #\n #  ##    #   #")
# Out:
# ### # #  ### ###
#  #  #  #  #   #
#  #  #  #  #   #
#  #  #  #  #   #
#  #  ##    #   #

# %%
#W2A19
print("Monday\nTuesday\nWednesday\nThursday\nFriday\nSaturday\nSunday")
# Out:
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday

# %%
#W2A20
print("January\nFebruary\nMarch\nApril\nMay\nJune\nJuly\nAugust\nSeptember\nOctober\nNovember\nDecember")
# Out:
# January
# February
# March
# April
# May
# June
# July
# August
# September
# October
# November
# December

# %%
#W2A21
print( "Hello, world","\nHello, world"*9)
# Out:
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
